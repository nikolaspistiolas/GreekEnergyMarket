# %%
from entsoe import EntsoePandasClient
import pandas as pd

api_key="7d2255de-e63f-4766-805a-0c0a1f6e7fa3"
client = EntsoePandasClient(api_key=api_key)
country_code = 'GR'

start = pd.Timestamp('20220429', tz='UTC')
end = pd.Timestamp('20220430', tz='UTC')

# %%
client.query_generation_forecast(country_code, start=  start, end = end)
# Out:
# 2022-04-28 03:00:00+03:00    1173.0
# 2022-04-28 04:00:00+03:00    1114.0
# 2022-04-28 05:00:00+03:00    1082.0
# 2022-04-28 06:00:00+03:00    1220.0
# 2022-04-28 07:00:00+03:00    1551.0
# 2022-04-28 08:00:00+03:00    1830.0
# 2022-04-28 09:00:00+03:00    1884.0
# 2022-04-28 10:00:00+03:00    1209.0
# 2022-04-28 11:00:00+03:00     840.0
# 2022-04-28 12:00:00+03:00     710.0
# 2022-04-28 13:00:00+03:00     900.0
# 2022-04-28 14:00:00+03:00     869.0
# 2022-04-28 15:00:00+03:00     802.0
# 2022-04-28 16:00:00+03:00     815.0
# 2022-04-28 17:00:00+03:00     945.0
# 2022-04-28 18:00:00+03:00    1706.0
# 2022-04-28 19:00:00+03:00    2775.0
# 2022-04-28 20:00:00+03:00    3500.0
# 2022-04-28 21:00:00+03:00    3674.0
# 2022-04-28 22:00:00+03:00    3166.0
# 2022-04-28 23:00:00+03:00    2611.0
# 2022-04-29 00:00:00+03:00    1964.0
# 2022-04-29 01:00:00+03:00    1697.0
# 2022-04-29 02:00:00+03:00    1275.0
# 2022-04-29 03:00:00+03:00    1388.0
# ...

# %%
client.query_wind_and_solar_forecast(country_code, start = start, end = end, psr_type=None)
# Out:
#                             Solar  Wind Onshore
# 2022-04-28 03:00:00+03:00     0.0         459.0
# 2022-04-28 04:00:00+03:00     0.0         515.0
# 2022-04-28 05:00:00+03:00     0.0         564.0
# 2022-04-28 06:00:00+03:00     4.0         619.0
# 2022-04-28 07:00:00+03:00   247.0         678.0
# 2022-04-28 08:00:00+03:00   897.0         712.0
# 2022-04-28 09:00:00+03:00  1656.0         726.0
# 2022-04-28 10:00:00+03:00  2282.0         783.0
# 2022-04-28 11:00:00+03:00  2707.0         868.0
# 2022-04-28 12:00:00+03:00  2925.0         976.0
# 2022-04-28 13:00:00+03:00  2968.0        1045.0
# 2022-04-28 14:00:00+03:00  2845.0        1081.0
# 2022-04-28 15:00:00+03:00  2550.0        1101.0
# 2022-04-28 16:00:00+03:00  2068.0        1102.0
# 2022-04-28 17:00:00+03:00  1423.0        1071.0
# 2022-04-28 18:00:00+03:00   722.0        1034.0
# 2022-04-28 19:00:00+03:00   187.0        1058.0
# 2022-04-28 20:00:00+03:00     0.0        1102.0
# 2022-04-28 21:00:00+03:00     0.0        1173.0
# ...

# %%
client.query_generation_per_plant(country_code, start = start, end = end, psr_type=None)
# Out:
#                                                     AGRAS  \
#                           Hydro Run-of-river and poundage
# 2022-04-28 03:00:00+03:00                             0.0
# 2022-04-28 04:00:00+03:00                             0.0
# 2022-04-28 05:00:00+03:00                             0.0
# 2022-04-28 06:00:00+03:00                             0.0
# 2022-04-28 07:00:00+03:00                             0.0
# 2022-04-28 08:00:00+03:00                            15.0
# 2022-04-28 09:00:00+03:00                            14.0
# 2022-04-28 10:00:00+03:00                            13.0
# 2022-04-28 11:00:00+03:00                            12.0
# 2022-04-28 12:00:00+03:00                            12.0
# 2022-04-28 13:00:00+03:00                            12.0
# 2022-04-28 14:00:00+03:00                             1.0
# 2022-04-28 15:00:00+03:00                             0.0
# 2022-04-28 16:00:00+03:00                             0.0
# ...

# %%
client.query_net_transfer_capacity_dayahead(country_code_from = 'IT', country_code_to = 'GR', start = start, end =end)
# Out:
# 2022-04-29 02:00:00+02:00    500.0
# 2022-04-29 03:00:00+02:00    500.0
# 2022-04-29 04:00:00+02:00    500.0
# 2022-04-29 05:00:00+02:00    500.0
# 2022-04-29 06:00:00+02:00    500.0
# 2022-04-29 07:00:00+02:00    500.0
# 2022-04-29 08:00:00+02:00    500.0
# 2022-04-29 09:00:00+02:00    500.0
# 2022-04-29 10:00:00+02:00    500.0
# 2022-04-29 11:00:00+02:00    500.0
# 2022-04-29 12:00:00+02:00    500.0
# 2022-04-29 13:00:00+02:00    500.0
# 2022-04-29 14:00:00+02:00    500.0
# 2022-04-29 15:00:00+02:00    500.0
# 2022-04-29 16:00:00+02:00    500.0
# 2022-04-29 17:00:00+02:00    500.0
# 2022-04-29 18:00:00+02:00    500.0
# 2022-04-29 19:00:00+02:00    500.0
# 2022-04-29 20:00:00+02:00    500.0
# 2022-04-29 21:00:00+02:00    500.0
# 2022-04-29 22:00:00+02:00    500.0
# 2022-04-29 23:00:00+02:00    500.0
# 2022-04-30 00:00:00+02:00    500.0
# 2022-04-30 01:00:00+02:00    500.0
# 2022-04-30 02:00:00+02:00    500.0
# Freq: 60T, dtype: float64

# %%
client.query_net_transfer_capacity_dayahead(country_code_from = 'BG', country_code_to = 'GR', start = start, end =end)
# Out:
# 2022-04-29 03:00:00+03:00    669.0
# 2022-04-29 04:00:00+03:00    669.0
# 2022-04-29 05:00:00+03:00    669.0
# 2022-04-29 06:00:00+03:00    669.0
# 2022-04-29 07:00:00+03:00    669.0
# 2022-04-29 08:00:00+03:00    669.0
# 2022-04-29 09:00:00+03:00    669.0
# 2022-04-29 10:00:00+03:00    669.0
# 2022-04-29 11:00:00+03:00    669.0
# 2022-04-29 12:00:00+03:00    669.0
# 2022-04-29 13:00:00+03:00    669.0
# 2022-04-29 14:00:00+03:00    669.0
# 2022-04-29 15:00:00+03:00    669.0
# 2022-04-29 16:00:00+03:00    669.0
# 2022-04-29 17:00:00+03:00    669.0
# 2022-04-29 18:00:00+03:00    669.0
# 2022-04-29 19:00:00+03:00    669.0
# 2022-04-29 20:00:00+03:00    669.0
# 2022-04-29 21:00:00+03:00    669.0
# 2022-04-29 22:00:00+03:00    669.0
# 2022-04-29 23:00:00+03:00    669.0
# 2022-04-30 00:00:00+03:00    669.0
# 2022-04-30 01:00:00+03:00    669.0
# 2022-04-30 02:00:00+03:00    669.0
# 2022-04-30 03:00:00+03:00    669.0
# Freq: 60T, dtype: float64

# %%
client.query_net_transfer_capacity_dayahead(country_code_from = 'AL', country_code_to = 'GR', start = start, end =end)
# Out:
# 2022-04-29 02:00:00+02:00    400.0
# 2022-04-29 03:00:00+02:00    400.0
# 2022-04-29 04:00:00+02:00    400.0
# 2022-04-29 05:00:00+02:00    400.0
# 2022-04-29 06:00:00+02:00    400.0
# 2022-04-29 07:00:00+02:00    400.0
# 2022-04-29 08:00:00+02:00    400.0
# 2022-04-29 09:00:00+02:00    400.0
# 2022-04-29 10:00:00+02:00    400.0
# 2022-04-29 11:00:00+02:00    400.0
# 2022-04-29 12:00:00+02:00    400.0
# 2022-04-29 13:00:00+02:00    400.0
# 2022-04-29 14:00:00+02:00    400.0
# 2022-04-29 15:00:00+02:00    400.0
# 2022-04-29 16:00:00+02:00    400.0
# 2022-04-29 17:00:00+02:00    400.0
# 2022-04-29 18:00:00+02:00    400.0
# 2022-04-29 19:00:00+02:00    400.0
# 2022-04-29 20:00:00+02:00    400.0
# 2022-04-29 21:00:00+02:00    400.0
# 2022-04-29 22:00:00+02:00    400.0
# 2022-04-29 23:00:00+02:00    400.0
# 2022-04-30 00:00:00+02:00    400.0
# 2022-04-30 01:00:00+02:00    400.0
# 2022-04-30 02:00:00+02:00    400.0
# Freq: 60T, dtype: float64

# %%
client.query_net_transfer_capacity_dayahead(country_code_from = 'TR', country_code_to = 'GR', start = start, end =end)
# Out:
# 2022-04-29 03:00:00+03:00    50.0
# 2022-04-29 04:00:00+03:00    50.0
# 2022-04-29 05:00:00+03:00    50.0
# 2022-04-29 06:00:00+03:00    50.0
# 2022-04-29 07:00:00+03:00    50.0
# 2022-04-29 08:00:00+03:00    50.0
# 2022-04-29 09:00:00+03:00    50.0
# 2022-04-29 10:00:00+03:00    50.0
# 2022-04-29 11:00:00+03:00    50.0
# 2022-04-29 12:00:00+03:00    50.0
# 2022-04-29 13:00:00+03:00    50.0
# 2022-04-29 14:00:00+03:00    50.0
# 2022-04-29 15:00:00+03:00    50.0
# 2022-04-29 16:00:00+03:00    50.0
# 2022-04-29 17:00:00+03:00    50.0
# 2022-04-29 18:00:00+03:00    50.0
# 2022-04-29 19:00:00+03:00    50.0
# 2022-04-29 20:00:00+03:00    50.0
# 2022-04-29 21:00:00+03:00    50.0
# 2022-04-29 22:00:00+03:00    50.0
# 2022-04-29 23:00:00+03:00    50.0
# 2022-04-30 00:00:00+03:00    50.0
# 2022-04-30 01:00:00+03:00    50.0
# 2022-04-30 02:00:00+03:00    50.0
# 2022-04-30 03:00:00+03:00    50.0
# Freq: 60T, dtype: float64

# %%
client.query_imbalance_volumes(country_code_to = 'GR', start = start, end =end)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-d58f1f155cfe> in <module>
# ----> 1 client.query_imbalance_volumes(country_code_to = 'GR', start = start, end =end)
#
# AttributeError: 'EntsoePandasClient' object has no attribute 'query_imbalance_volumes'

# %%
import tensorflow as tf
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

engine = create_engine('postgresql://xatziandreou:ggmu!xatziandreou@192.168.1.225/Markets')
data = pd.read_sql('SELECT * FROM import_forecast_tm  ',engine)

# %%
data.head()
# Out:
#                  Date  ALBANIA  BULGARIA  ITALY  NORTH MACEDONIA  TURKEY
# 0 2020-11-01 00:00:00     50.0     338.0    0.0             78.0    53.0
# 1 2020-11-01 01:00:00     50.0     338.0    0.0             78.0    53.0
# 2 2020-11-01 02:00:00     37.0     338.0    0.0             78.0    53.0
# 3 2020-11-01 03:00:00     37.0     338.0    0.0             78.0    53.0
# 4 2020-11-01 04:00:00     37.0     338.0    0.0             78.0    53.0

# %%
parks = pd.read_sql(f'select "Prefix", "IsMarketActive","Start_dispatch_day","Power" from parks  where "IsMarketActive" >= {datetime.datetime(2022,4,12)} ',engine)
